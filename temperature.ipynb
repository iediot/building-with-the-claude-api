# %%
from platform import system

from dotenv import load_dotenv

load_dotenv()

from anthropic import Anthropic

client = Anthropic()
# 4.7 and later models no longer accept temperature
model = "claude-sonnet-4-6"

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature

    }
    if system:
        params["system"] = system
    message = client.messages.create(**params)
    for block in message.content:
        if block.type == "text":
            return block.text

# %%
messages = []

add_user_message(
    messages,
    "Generate a one sentence movie idea",
)

# temperature: 1.0 - more creative
#              0.0 - less creative
answer = chat(messages, temperature=1.0)

answer
# Out:
# "Here's a movie idea:\n\n**A retired safecracker with early-onset Alzheimer's must pull off one final heist to fund his own care — but can no longer fully trust his own memory of the plan.**"
