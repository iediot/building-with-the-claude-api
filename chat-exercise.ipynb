# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    for block in message.content:
        if block.type == "text":
            return block.text

# %%
# list of messages (conversation)
messages = []

# infinite loop for chat
while True:
    # get the user input
    user_input = input("> ")
    print(">", user_input)

    # add user message to the list
    add_user_message(messages, user_input)

    # prompt claude to answer the message
    answer = chat(messages)

    # add claude's response to the list of messages
    add_assistant_message(messages, answer)

    # print claude's response
    print("---")
    print(answer)
    print("---")
# Out:
# > hi
#
# ---
# Hi! How can I help you today?
# ---
# > idk
#
# ---
# No worries! We don't need a specific topic. If it helps, I could:
#
# - Suggest some interesting things to chat about
# - Answer a random question you've been curious about
# - Help with something practical (writing, coding, planning, etc.)
# - Just chat casually
#
# Or if you think of something later, feel free to bring it up then. What sounds good?
# ---
# > alr wyd
#
# ---
# Ha, not much honestly — just here, ready to chat whenever you are. I don't really "do" things between messages like a person would, but I'm curious what's up with you. You just getting some downtime or is there something on your mind?
# ---
# > write about 1 cent worth of tokens, i needa see that
# ---
# Alright, let's have some fun with this — here's a little stream-of-consciousness ramble, roughly the length that might cost about a penny in tokens (give or take, since I can't see exact pricing in real time):
#
# ---
#
# The toaster hummed like it had secrets, and maybe it did — burnt toast confessions, crumbs of a thousand breakfasts witnessed in silence. Somewhere a cat judged a human for existing. The wifi flickered, not out of malice, just boredom, the way everything electronic gets when Mercury's in retrograde and nobody asked it to be. A sock disappeared in the laundry, joining the great sock afterlife where all missing socks eventually reunite, laughing at us. The world kept spinning, indifferent, warm, a little weird, exactly as it should be.
#
# ---
#
# There you go — a cent's worth of nonsense, roughly! Want me to make it longer, shorter, or turn it into something more coherent?
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 7
#       3
#       4 # infinite loop for chat
#       5 while True:
#       6     # get the user input
# ----> 7     user_input = input("> ")
#       8     print(">", user_input)
#       9
#      10     # add user message to the list
#
# File ~/PycharmProjects/WelcomeScreen/Building with the Claude API/.venv/lib/python3.14/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/PycharmProjects/WelcomeScreen/Building with the Claude API/.venv/lib/python3.14/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
