# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to Evaluate the Solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\n\nconfig = {\n    \"FunctionName\": \"S3EventProcessor\",\n    \"Runtime\": \"python3.11\",\n    \"Handler\": \"index.lambda_handler\",\n    \"Role\": \"arn:aws:iam::123456789012:role/lambda-s3-execution-role\",\n    \"Timeout\": 60,\n    \"MemorySize\": 256,\n    \"Description\": \"Lambda function to process S3 events\",\n    \"Environment\": {\n        \"Variables\": {\n            \"BUCKET_NAME\": \"my-s3-bucket\"\n        }\n    },\n    \"Architectures\": [\"x86_64\"],\n    \"EphemeralStorage\": {\n        \"Size\": 512\n    }\n}\n\nwith open(\"lambda_config.json\", \"w\") as f:\n    json.dump(config, f, indent=2)\n\nprint(json.dumps(config, indent=2))\n",
#     "test_case": {
#       "task": "Create a JSON configuration file for an AWS Lambda function that processes S3 events. The configuration should specify the function name, runtime, handler, and IAM role ARN.",
#       "format": "json",
#       "solution_criteria": "Valid JSON with required fields: FunctionName, Runtime, Handler, Role. Should follow AWS Lambda naming conventions and include proper string formatting for ARNs."
#     },
#     "score": 3.5,
#     "reasoning": "The solution correctly creates a valid JSON configuration with all required fields and proper AWS formatting. However, it addresses only the Lambda function configuration itself and omits the S3 event source mapping/trigger setup that would be necessary for the function to actually process S3 events. The placeholder account ID should be clearly documented as needing replacement. The core requirement is met, but the solution is incomplete for the stated purpose of processing S3 events."
#   },
#   {
#     "output": "\nimport json\nimport re\nfrom typing import Dict\nfrom urllib.parse import urlparse\n\ndef parse_s3_key(s3_key: str) -> Dict[str, str]:\n    # Handle s3://bucket/key format\n    if s3_key.startswith('s3://'):\n        parsed = urlparse(s3_key)\n        bucket_name = parsed.netloc\n        object_key = parsed.path.lstrip('/')\n    else:\n        # Handle bucket/key format (assuming key doesn't start with s3://)\n        parts = s3_key.split('/', 1)\n        if len(parts) == 2:\n            bucket_name = parts[0]\n            object_key = parts[1]\n        else:\n            bucket_name = s3_key\n            object_key = \"\"\n    \n    # Extract file extension and object name\n    if '.' in object_key:\n        last_dot_index = object_key.rfind('.')\n        file_extension = object_key[last_dot_index + 1:]\n        object_name = object_key[:last_dot_index]\n    else:\n        file_extension = \"\"\n        object_name = object_key\n    \n    return {\n        \"bucket_name\": bucket_name,\n        \"object_name\": object_name,\n        \"file_extension\": file_extension\n    }\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        \"s3://my-bucket/path/to/file.txt\",\n        \"my-bucket/path/to/file.txt\",\n        \"s3://my-bucket/file.json\",\n        \"my-bucket/documents/report.pdf\",\n        \"s3://data-bucket/archive.tar.gz\"\n    ]\n    \n    for test in test_cases:\n        print(json.dumps(parse_s3_key(test)))\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 object key and returns a dictionary with the bucket name, object name, and file extension extracted from the key path.",
#       "format": "python",
#       "solution_criteria": "Function should correctly parse S3 keys in formats like 'bucket/folder/file.txt' or 'bucket/path/to/object.json'. Should handle edge cases like keys without extensions or nested folders."
#     },
#     "score": 8.0,
#     "reasoning": "The solution demonstrates good understanding of S3 key formats and implements a working parser for standard file extensions. However, it has a significant logical flaw in handling compound extensions like .tar.gz, which are common in AWS workflows. The rfind('.') approach only captures the last extension segment, not multi-part extensions. Additionally, the lack of input validation means edge cases like None or empty strings would cause unexpected behavior. The solution works for basic cases but needs refinement for production use."
#   },
#   {
#     "output": "\n^arn:aws:iam::\\d{12}:role/[\\w+=,.@-]+$\n",
#     "test_case": {
#       "task": "Create a regular expression pattern that validates AWS IAM role ARNs. The pattern should match ARNs in the format: arn:aws:iam::ACCOUNT_ID:role/ROLE_NAME",
#       "format": "regex",
#       "solution_criteria": "Pattern must match valid IAM role ARNs, validate 12-digit account IDs, allow alphanumeric characters and hyphens in role names, and reject malformed ARNs."
#     },
#     "score": 8.5,
#     "reasoning": "The pattern successfully validates the core ARN structure and account ID format, making it functional for most real-world use cases. However, it deviates from strict AWS IAM naming conventions by accepting invalid characters (=, +, comma, period) that AWS does not permit in role names. The corrected pattern should be: ^arn:aws:iam::\\d{12}:role/[\\w-]+$ to match only valid role name characters."
#   }
# ]
